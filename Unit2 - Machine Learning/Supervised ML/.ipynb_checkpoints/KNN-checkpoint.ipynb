# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\SUMEET\Downloads\teleCust1000t.csv")
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
df.isnull().sum()
# Out:
# region     0
# tenure     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# employ     0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# region     0
# tenure     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# employ     0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df["income"]=df["income"].astype(int)
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9      64   4       5     0.0
# 1         3      11   33        1        7     136   5       5     0.0
# 2         3      68   52        1       24     116   1      29     0.0
# 3         2      33   33        0       12      33   2       0     0.0
# 4         2      23   30        1        9      30   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0      27   3       0     0.0
# 996       1       7   34        0        2      22   5       5     0.0
# 997       3      67   59        0       40     944   5      33     0.0
# 998       3      70   49        0       18      87   2      22     0.0
# 999       3      50   36        1        7      39   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
df["retire"]=df["retire"].astype(int)
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9      64   4       5       0
# 1         3      11   33        1        7     136   5       5       0
# 2         3      68   52        1       24     116   1      29       0
# 3         2      33   33        0       12      33   2       0       0
# 4         2      23   30        1        9      30   1       2       0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0      27   3       0       0
# 996       1       7   34        0        2      22   5       5       0
# 997       3      67   59        0       40     944   5      33       0
# 998       3      70   49        0       18      87   2      22       0
# 999       3      50   36        1        7      39   3       3       0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
df.describe()
# Out:
#           region       tenure          age      marital      address  \
# count  1000.0000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.0220    35.526000    41.684000     0.495000    11.551000
# std       0.8162    21.359812    12.558816     0.500225    10.086681
# min       1.0000     1.000000    18.000000     0.000000     0.000000
# 25%       1.0000    17.000000    32.000000     0.000000     3.000000
# 50%       2.0000    34.000000    40.000000     0.000000     9.000000
# 75%       3.0000    54.000000    51.000000     1.000000    18.000000
# max       3.0000    72.000000    77.000000     1.000000    55.000000
#
#             income           ed       employ       retire       gender  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     77.535000     2.671000    10.987000     0.047000     0.517000
# std     107.044165     1.222397    10.082087     0.211745     0.499961
# ...

# %%
import seaborn as sns

# %%
# Box plot for income based on gender
plt.figure(figsize=(8, 6))
sns.boxplot(x='gender', y='income', data=df)
plt.title('Income Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# # Income Distribution by gender

# %%
# Analyze based on income
plt.figure(figsize=(12, 6))
sns.histplot(df['income'], bins=30, kde=True)
plt.title('Distribution of Income')
plt.xlabel('Income')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # As the salary increases Count of employees having high salay decreases

# %%
# Countplot for gender based on region
plt.figure(figsize=(10, 6))
sns.countplot(x='region', hue='gender', data=df)
plt.title('Count of Customers by Gender in Each Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # difference of salaries in different regions

# %%
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9      64   4       5       0
# 1         3      11   33        1        7     136   5       5       0
# 2         3      68   52        1       24     116   1      29       0
# 3         2      33   33        0       12      33   2       0       0
# 4         2      23   30        1        9      30   1       2       0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0      27   3       0       0
# 996       1       7   34        0        2      22   5       5       0
# 997       3      67   59        0       40     944   5      33       0
# 998       3      70   49        0       18      87   2      22       0
# 999       3      50   36        1        7      39   3       3       0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
x = df.drop(columns="custcat")
x
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9      64   4       5       0
# 1         3      11   33        1        7     136   5       5       0
# 2         3      68   52        1       24     116   1      29       0
# 3         2      33   33        0       12      33   2       0       0
# 4         2      23   30        1        9      30   1       2       0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0      27   3       0       0
# 996       1       7   34        0        2      22   5       5       0
# 997       3      67   59        0       40     944   5      33       0
# 998       3      70   49        0       18      87   2      22       0
# 999       3      50   36        1        7      39   3       3       0
#
#      gender  reside
# 0         0       2
# 1         0       6
# 2         1       2
# 3         1       1
# ...

# %%
y = df["custcat"]
y
# Out:
# 0      1
# 1      4
# 2      3
# 3      1
# 4      3
#       ..
# 995    1
# 996    1
# 997    4
# 998    3
# 999    2
# Name: custcat, Length: 1000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit(x).transform(x.astype(float))
x1= pd.DataFrame(x)
x1
# Out:
#            0         1         2         3         4         5         6   \
# 0   -0.026968 -1.055125  0.184505  1.010051 -0.253034 -0.126506  1.087753
# 1    1.198836 -1.148806 -0.691812  1.010051 -0.451415  0.546450  1.906227
# 2    1.198836  1.521092  0.821826  1.010051  1.234819  0.359517 -1.367671
# 3   -0.026968 -0.118319 -0.691812 -0.990050  0.044536 -0.416251 -0.549196
# 4   -0.026968 -0.586722 -0.930808  1.010051 -0.253034 -0.444291 -1.367671
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  1.198836 -1.195646 -0.213821 -0.990050 -1.145747 -0.472331  0.269278
# 996 -1.252771 -1.336167 -0.612147 -0.990050 -0.947366 -0.519064  1.906227
# 997  1.198836  1.474252  1.379482 -0.990050  2.821863  8.098513  1.906227
# 998  1.198836  1.614773  0.582830 -0.990050  0.639678  0.088466 -0.549196
# 999  1.198836  0.677967 -0.452817  1.010051 -0.451415 -0.360172  0.269278
#
#            7         8         9         10
# ...
